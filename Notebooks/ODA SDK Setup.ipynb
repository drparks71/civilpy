# %% [markdown]
# # ODA Trial Setup
#
# Register for an account [here](https://www.opendesign.com/) and log-in once your trial is activated.
#
# Within the source folder will be an `exe` folder, click that, select the build for your system for instance mine is `vc16_amd64dll` it's important to ensure the source files you download match your computer architecture (amd64 for me) and that your visual studio configuration matches your source files (Visual C++ 16).
#
# Run `TrialActivator.exe` to authorize your device to execute the SDKs

# %% [markdown]
# <img src="......" alt="Red dot" />

# %% [markdown]
# This should read your devices ID and register it to be allowed to use the various SDKs.

# %% [markdown]
# # CLion Configuration
#
# The tools are built using Microsoft Visual C++, which can probably be setup in Visual Studio. I personally despise visual studio, and would rather write code in an IDE that runs code rather than spend my life trying to get VS configured correctly. You can probably do it in Visual Studio Code, I never gave it a chance because I hate Visual Studio so much.
#
# Here's how I recommend setting it up instead.
#
# [Get CLion,](https://www.jetbrains.com/clion) (Don't think it's free, but you get what you pay for.)
#
# [Get Visual Studio](https://visualstudio.microsoft.com/)
#
#
# Configure your CLion build settings to utilize the Visual Studio toolchain:

# %% [markdown]
# <img src='......'>

# %%
import base64

with open(r"D:\Jetbrains\PycharmProjects\civilpy\Notebooks\res\imgs\ODA\Build_Settings.jpg", "rb") as image_file:
    encoded_string = base64.b64encode(image_file.read())
    print(encoded_string)
