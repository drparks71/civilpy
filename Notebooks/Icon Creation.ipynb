# %%
from PIL import Image

# %%
image = Image.open(
    r"C:\Users\dane.parks\OneDrive - Michael Baker International\Pictures\icons\Silicorn Valley\_silicorn ico.jpg"
)

# %%
image_16 = image.resize((16, 16))
image_16
# Out:
# <PIL.Image.Image image mode=RGB size=16x16>

# %%
image_32 = image.resize((32, 32))
image_32
# Out:
# <PIL.Image.Image image mode=RGB size=32x32>

# %%
image_64 = image.resize((64, 64))

image_64.save(
    r"C:\Users\dane.parks\OneDrive - Michael Baker International\Pictures\icons\Silicorn Valley\silicorn ico_64.jpg"
)

image_64
# Out:
# <PIL.Image.Image image mode=RGB size=64x64>

# %%
image_128 = image.resize((128, 128))

image_128.save(
    r"C:\Users\dane.parks\OneDrive - Michael Baker International\Pictures\icons\Silicorn Valley\silicorn ico_128.jpg"
)

image_128
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
image_192 = image.resize((192, 192))
image_192.save(
    r"C:\Users\dane.parks\OneDrive - Michael Baker International\Pictures\icons\Silicorn Valley\silicorn ico_192.jpg"
)

# %%
image_256 = image.resize((256, 256))

image_256.save(
    r"C:\Users\dane.parks\OneDrive - Michael Baker International\Pictures\icons\Silicorn Valley\silicorn ico_256.jpg"
)

image_256
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
image_512 = image.resize((512, 512))

image_512.save(
    r"C:\Users\dane.parks\OneDrive - Michael Baker International\Pictures\icons\Silicorn Valley\silicorn ico_512.jpg"
)

image_512
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
