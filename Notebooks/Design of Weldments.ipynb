# %% [markdown]
# # Design of Weldments
#
# [Lincoln Electric's "Design of Weldments"](https://www.jflf.org/ProductDetails.asp?ProductCode=DW) by Omer W. Blodgett
#
#
# <div class="warning" style='padding:0.1em; background-color:#E9D8FD; color:#69337A'>
#     <span>
#         <p style='margin-top:1em; text-align:center'>
#             <b>Notes written by Dane Parks will appear in these boxes</b>
#         </p>
#         <p style='margin-left:1em'>
#         Note: The original book is for designing machine components, but it's generally considered a fantastic resource for all weld design and one of the foundational documents of the field. For that reason, it was chosen as a starting point while developing python formulas for weld design. Additional requirements will have to be given consideration to ensure the formualas are applied in a manner consistent with the requirements outlined in additional regulatory standards like AASHTO, AISC and AREMA, when required.
#         </p>
#     </span>
# </div>

# %% [markdown]
# ## Table of contents
#
# 1. \- **<u>Design Approach</u>**
#     1.1 - Progress through Welded Steel Construction
#     1.2 - Systematic Desing of Weldments
#     1.3 - Problem Definition
#     1.4 - Designer's Guide to Welded Steel Construction
#     1.5 - Redesigning by Means of Equivalent Sections
# 2. \- **<u>Load and Stress Analysis</u>**
#     2.1 - Loads and Their Evaluation
#     2.2 - Properties of Materials
#     2.3 - Properties of Sections
#     2.4 - Analysis of Tension
#     2.5 - Analysis of Compression
#     2.6 - Analysis of Bending
#     2.7 - Analysis of Combined Stresses
#     2.8 - Strength of Curved Beams
#     2.9 - Deflection by Bending
#     2.10 - Shear Deflection in Beams
#     2.11 - Deflection of Curved Beams
#     2.12 - Buckling of Plates
# 3. \- **<u>Special Design Conditions</u>**
#     3.1 - Designing for Impact Loads
#     3.2 - Designing for Fatigue Loads
#     3.3 - Designing for Improved Vibration Control
#     3.4 - Dimensional Stability
#     3.5 - Elastic Matching
#     3.6 - Designing for Torsional Loading
# 4. \- **<u>Stationary-Member Design<u>**
#     4.1 - How to Design Machine Bases
#     4.2 - How to Design Flat Tables
#     4.3 - How to Brace or Stiffen a Member
#     4.4 - How to Design Steel Frames
#     4.5 - Columns, Legs and Feet
#     4.6 - Flat Containers, Cylinders and Shells
#     4.7 - Design of Container Hangers and Supports
#     4.8 - How to Design Gear Housings
#     4.9 - Motors and Generators
#     4.10 - How to Design Bearing Supports
#     4.11 - How to Design Bosses and Pads
#     4.12 - How to Design Machine Brackets
# 5. \- **<u>Rotating-Member Design</u>**
#     5.1 - How to Design Flywheels
#     5.2 - How to Design Pulleys and Sheaves
#     5.3 - How to Design Steel Rolls
#     5.4 - How to Design Large Gears
# 6. \- **<u>Joint Design and Production<u>**
#     6.1 - Weldability of Steel
#     6.2 - Joint Design
#     6.3 - Determining Weld Size
#     6.4 - Estimating Welding Costs
#     6.5 - Control of Shrinkage and Distortion
# 7. \- **<u>Reference Design Formulas</u>**
#     7.1 - Beam Diagrams and Formulas
#     7.2 - Circular Flat Plates
#     7.3 - Torsional Members
#     7.4 - Frame Diagrams adn Formulas
#     7.5 - Thin Curved Bars
#     7.6 - Thin Circular Rings
#     7.7 - Thing Rings Under Internal pressure
# 8. \- **<u>Miscellaneous Tables</u>**  <!-- Typo in book - All subsections listed as 8.1 -->
#     8.1 - Naperian (Natural) Log Tables
#     8.2 - Metric Conversion Factors
#     8.3 - Weights of Carbon Steel Bars
#     8.4 - SAE Steel Numbering System
#     8.5 - Welding Processes Chart

# %% [markdown]
# ## Symbols and Their Definitions
#
# $ \alpha $ - Angular acceleration ($ \text{radians/s}^2 $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Included angle of beam curvature ($ \text{degrees} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Form factor
# $ \Delta $ - Perpendicular deflection ($ \text{in.} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Bending ($ \Delta_b $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Shear ($ \Delta_s $)
# $ \epsilon $ - Unit strain
# &nbsp;&nbsp;&nbsp;&nbsp; Elongation
# &nbsp;&nbsp;&nbsp;&nbsp; Contraction ($ \text{in./in.} $)
# $ \epsilon_s $ - Unit shear strain ($ \text{in./in.} $)
# $ v $ - Poisson's ration (steel = 0.3 typically)
# $ \omega $ - leg size of fillet weld ($ \text{in.} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;rate of angular motion about an axis ($ \text{radians/sec} $)
# $ \phi $ - unit angular twist ($ \text{radians/linear inch} $)
# $ \Sigma $ - Sum
# $ \sigma $ - Normal Stress (tensile or compressive, $ \text{psi} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Strength ($ \text{psi}$)
# $ \tau $ - Shear stress ($ \text{psi} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Shear strength ($ \text{psi} $)
# $ \theta $ - Angle of twist ($ \text{radians} $, $ \text{1 radian = 57.3 degrees} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Angle of rotation ($ \text{radians} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Any specified angle
# <br><br>
# $ a $ - Area of a section beyond plane where stress is desired or applied ($ \text{in}^2$)
# $ b $ - Width of section ($ \text{in.} $)
# $ c $ - Distance from neutral axis to extreme fiber ($ \text{in.} $)
# $ d $ - Depth of section ($ \text{in.} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Moment arm of force ($ \text{in.} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Distance ($ \text{in.} $)
# $ e $ - Eccentricity of applied load ($ \text{in.} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Total axial strain ($ \text{in.} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Moment arm of force ($ \text{in.} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Effective width ($ \text{in.} $)
# $ f $ - Force per linear inch of weld $ \text{lbs/in.} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Horizontal shear force ($ \text{lbs/in.} $
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(Vectorial) Resultant force ($ \text{lbs/in.} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Allowable strength of weld ($ \text{lbs/in.} $)
# $ g $ - Acceleration of gravity ($ \text{386.1 in./s}^2 $)  <!-- Book had 386.4 -->
# $ h $ - Height
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Height of fall
# $ k $ - Any specified constant or amplification factor
# $ m $ - Mass
# $ n $ - Distance of section's neutral axis from reference axis ($ \text{in.} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Number of units in series
# $ p $ - Internal pressure ($ \text{psi} $)
# $ r $ - Radius ($ \text{in.} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Radius of Gyration
# $ s $ - Length of curved beam segment ($ \text{in.} $)
# $ t $ - Thickness of section ($ \text{in.} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Time ($ \text{min} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Time interval ($ \text{s} $)
# $ u $ - Material's tensile modulus of resilience ($ \text{in.-lb/in.}^3 $)
# $ u_u $ - Material's ultimate energy resistance ($ \text{in.-lb/in.}^3 $)
# $ w $ - Uniformly distributed load ($ \text{lbs/linear in.} $)
# $ x $ - Length of moment arm (curved beam)
# $ y $ - Distance of area's center of gravity to neutral axis of entire section ($ \text{in.} $)
# <br><br>
# $ A $ - Area ($ \text{in.}^2 $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Total area of cross-section
# $ E $ - Modulus of elasticity, tension ($ \text{psi} $)
# $ E_s $ - Modulus of Elasticity in shear ($ \text{psi} $)
# $ E_t $ - Tangential modulus of elasticity ($ \text{psi} $)
# $ E_k $ - Kinetic energy
# $ E_p $ - Potential energy
# $ F $ - Total force ($ \text{lbs} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Radial force ($ \text{lbs} $)
# $ I $ - Moment of inertia ($ \text{in}^4 $)
# $ J $ - Polar moment of inertia ($ \text{in}^4 $)
# $ K $ - Ration of minimum to maximum load (fatigue)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Any specified constant
# $ L $ - Length of member ($ \text{in. or ft.} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Span between supports ($ \text{in.} $)
# $ L_e $ - Effective length of column
# $ M $ - Bending moment ($ \text{in.-lbs} $)
# $ M_o $ - Applied bending moment ($ \text{in.-lbs} $)
# $ N $ - Number of service cycles
# $ P $ - Concentrated Load
# $ Q $ - Shear center
# $ R $ - Reaction ($ \text{lbs} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Torsional resistance of member ($ \text{in.}^4 $)
# $ S $ - Section modulus ($ \text{in}^3 $) = I/c
# $ T $ - Torque or twisting moment ($ \text{in.-lbs} $)
# $ U $ - Stored energy
# $ V $ - Vertical shear load ($ \text{lbs} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Shear reaction
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Velocity
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Volume
# $ W $ - Total load ($ \text{lbs} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Weight ($ \text{lbs} $)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Total width ($ \text{in.} $)
# <br><br>
# $ C.G. $ - Center of gravity
# $ HP $ - Horsepower
# $ N.A. $ - Neutral Axis
# $ RPM $ - Revolutions per minute

# %% [markdown]
# # 1. Design Approach

# %% [markdown]
# ## 1.1 Progress Through Welded Steel Construction
#
# Provides history and background of welding process developement. The goal of weld design is to produce the maximum performance for the least cost. Outlines the benefits of designing and implementing design solutions with welded steel.

# %% [markdown]
# ## 1.2 Systemic Design of Weldments

# %% [markdown]
# ### 1.2.1 Design requirements
#
# Questions to answer:
#
# 1. How to select the most efficient type of section
# 2. How to quickly determine the dimensions of this section
# 3. Whether stiffeners should be used
# 4. Stiffener size and placement
#
# Previous design was done empirically from past experience, resulting in designs that "look heavy enough" but in reality are overdesigned. This results in higher material costs, higher fabrication costs and more welding than necessary.
#
# Modern design processes rely on mathematical calculations. This allows for more efficient designs and optimizations.
#
# This document offers a sound basis for mathematical analysis and solution of machine design problems related to frames, bases, and other welded steel members. The methods presented here simplify the use of stress analysis and the complicated, time consuming design formulas that must be used.

# %% [markdown]
# ### 1.2.2 - Select the Design Requirements
#
# Two primary approaches are available
#
# 1. A single part at a time
# 2. The whole Machine
#
# <b><u>Advantages of Part by Part Design</u></b>
#
# Allows the opportunity of incrementally designing welded components while gradually shifting processes away from bolted connections/castings. Reduces the costs of obsolescence of existing equipment for shops and provides opportunity to retrain/reskill workforce to handle the additional requirements involved in welded steel production.
#
# Welded steel components designed part-by-part can be implemented in existing machines produced by a shop as replacement components.
#
# <b><u>Advantages of New Model Design</u></b>
#
# With this method, the previous designs do not restrict the designer. Pieces can be made of fewer and more complex components. Less components means less welding and associated costs savings. A single weldment can replace several castings, less machining is generally required to facilitate assembly. The total effect is to improve appearance and performance while reducing weight and cost.
#
# <div class="warning" style='padding:0.1em; background-color:#E9D8FD; color:#69337A'>
#     <span>
#         <p style='margin-top:1em; text-align:center'>
#             <b>Notes on how this relates to bridge and transportation design</b>
#         </p>
#         <p style='margin-left:1em'>
#         Since bridge design and construction is generally different than the design of steel structures in the manufacturing industry, I'll try to include these notes where the original document "Design of Steel Weldments" offers contradictory advice or otherwise supplies information that may not be able to be used in transporation focused structural engineering.<br><br>Structures are typically designed as singular systems. Generally, the more imporant consideration when designing welds in steel structures is whether the proposed design is "constructible". Care should be taken to not design components that can't be shipped, or that lack the necessary clearances for fabricators to actually build the structure. Often we make sacrificies in the areas of efficiency or costs in order to make field assembly easier. This can frequently result in bolted assemblies being selected in areas where shop welding would have been preferrable, but due to other constraints, field welding would have to be utilized.<br><br>Often it is easier to field bolt components like splices than it is to attempt to weld structures in the field.</p>
#     </span>
# </div>

# %% [markdown]
# ### 1.2.3 Selecting a Basis for Design
#
# 1. Previous Design
# 2. Loading Only
#
# <u><b>Design Based on a Previous Design</b><u>
#
# There are advantages for starting from a previous design. The previous design is somewhat proven, and potentially provides lessons in what works and doesn't. It's disadvantageous in that it channels one's thinking in terms of the previous design and blocks creative processes in developing entirely new concepts. Any faults in the previous designs tend to be perpetuated.
#
# The tables of equivalent sections in Section 1.5 or companion nomographs are used for both strength and rigidity when the design is based on the previous design.
#
# <u><b>Design Based on Loading Only</u></b>
#
# A new design based purely on loading allows the designer to utilize their creativity to the fullest extent. There are additional efforts required in determining the the value and type of load in some cases. It's also necessary to determine the stress allowable (in a strength design) or the deflection allowable (in a rigidity design).
#
# Design formulas are used for both strength and rigidity when the design is based on loading only.

# %% [markdown]
# ### 1.2.4 Selecting Design Criterion
#
# 1. Strength only
# 2. In addition, rigidity
# 3. No Load
#
# This choice should be made for the whole machine, and then reviewed as each member is designed. In some cases, the machine is basically designed for strength while portions are designed for rigidity.
#
# <b><u>Designing for Strength Only</u></b>
#
# All designs must have sufficient strength so the members will not fail by breaking or yielding when subjected to the normal operating loads or to reasonable overload. Strength designs are common in road machinery, farm implements, motor brackets, etc.
#
# If a weldment's design is based on a prior casting design, the equivalent-strength relationships are used. If a new design is based directly on calculated loading, the design formulas for strength are used.
#
# <b><u>Designing for Rigidity in Addition to Strength</b><u>
#
# In some applications a dsign developed for only sufficient strength would produce a section which might deflect excessively when loaded. The section must be made still heavier for sufficient rigidity as well as strength. Rigidity designs are common in machine tools.
#
# If the steel weldment's design is based on a prior design, the equivalent-rigidity relationships are used. If a new design is based directly on calculated loading, teh design formulas for rigidity are used.
#
# <b><u>Designing for No Load</b></u>
#
# Some parts can be classed as "no load". These are members expected to serve with practically no load and have no specific strength or rigidity requirements (ie zero-force members). Typical no-load designs are gear guards, covers for access holes, splash and dust shields, etc. Such members occasionally present a noise problem, but the solution to this problem is not rigidity, nor does it affect the basic design. Noise is discussed in section 3.3 on vibration control.

# %% [markdown]
# ### 1.2.5 Design Formulas
#
# Three factors are always present in a design formula,
#
# 1. Load
# 2. Member
# 3. Stress and Strain
#
# All three have a relationship with each other in a given formula, depending on the type of load. If any two of these three terms are known, the third may be found. Therefore, all problems of design will essentially be one of the following:
#
# 1. To find the resulting internal stress or strain caused by an external load on a given member
# 2. To find an external load which may be placed on a given member for any allowable stress or strain
# 3. To select or design a certain member to carry a given load within a given allowable stress or strain.
#
# A member is useful only when it carries a load.  The load (force) stresses the member, which results in a strain measured as elongation, contraction, deflection or angular twist.
#
# Therefore, every member must be designed to carry a certain type of load within a certani allowable stress or within a certain allowable strain.
#
# In designing within these allowables, the designer should select the most efficient material and the most efficient section, size and shape. The combined properties of the material and properties of the section determine the ability of the member to cary a given load.
#
# The components of design formulas related to each of these factors are charted in Table 1.
#
# <b><u>Table 1 (3 tables in notebook format)</b></u>

# %% [markdown]
# #### <center>I. Load</center>
#
# | Application |    Type        |         Value          |
# |:------------|:---------------|:-----------------------|
# | a. steady   | a. tension     | a. force, pounds       |
# | b. impact   | b. compression | b. moment, inch-pounds |
# | c. variable | c. bending     | c. torque, inch-pounds |
# |             | d. torsion     |                        |

# %% [markdown]
# #### <center>II. Member </center>
#
# | Material                                       | Section                                                      |
# |:-----------------------------------------------|:-------------------------------------------------------------|
# | a. tensile strength, $ \sigma_t $              | a. area, A                                                   |
# | b. compressive strength, $ \sigma_c $          | b. length, L                                                 |
# | c. shear strength, $ \tau $                    | c. moment of inertia, I<br>(stiffness factor in bending)     |
# | d. fatigue strength                            | d. section modulus, S<br>(strength factor in bending)        |
# | e. modulus of elasticity<br>(tension), $ E_t $ | e. torsional resistance, R<br>(stiffness factor in twisting) |
# | f. modulus of elasticity<br>(shear), $ E_s $   | f. radius of gyration, r                                     |

# %% [markdown]
# #### <center>III. Stress and Strain </center>
#
# | Stress                                         | Strain                                                                  |
# |:-----------------------------------------------|:------------------------------------------------------------------------|
# | a. tensile stress, $ \sigma_t $                | a. resulting deformation,<br>elongation or or contraction, $ \epsilon $ |
# | b. compressive stress, $ \sigma_c $            | b. vertical deflection $ \Delta $                                       |
# | c. shear stress, $ \tau $                      | c. angular twist, $ \theta $                                            |

# %% [markdown]
# ### 1.2.6 The Load Factor in Design Formulas
#
# The given information about the load is not complete unless the type, method of application and the value are fully known.
#
# 1. Type
#     1. Tension
#     2. Compression
#     3. Bending
#     4. Torsion
# 2. Application
#     1. Steady
#     2. Impact
#     3. Variable
# 3. Value
#     1. Force, in pounds
#     2. Moment, in inch-pounds
#     3. Torque, in inch-pounds

# %% [markdown]
# ### 1.2.7 The Member Factor in Design Formulas

# %% [markdown]
# #### 1.2.7.1 Property of Material
#
# The material used in a member has certain physical properties. Allowable loads are determined by applying a factor of safety to the ultimate strength (tension, compression, or shear) or, in some cases, to the yield strength of the material.
#
# These values are used in all strength problems. The modulus of elasticity is used in all rigidity problems.
#
# $ \sigma_t $ = allowable tensile strength
# $ \sigma_c $ = allowable comressive strength
# $ \tau $ = allowable shear strength
# $ E $ = modulus of elasticity in tension
# $ E_s $ = modulus of elasticity in shear

# %% [markdown]
# #### 1.2.7.2 Property of Section
#
# A members cross-section affects its performance. The influence is measured by one of several properties of the section. The sections area is the critical property when the load is axial or shear.
#
# $ A $ = Area of cross-section
# $ L $ = Unsupported length of member
# $ S $ = Section modulus, strength factor when member is used as a beam
# $ I $ = Moment of inertia, rigidity or stiffness factor when member is used as a beam
# $ R $ = Torsional resistance
#
# The performance of a member is predetermined by the product of the appropriate property of the material and the corresponding property of the section. Since the engineer designs for strength only or, in addition, for rigidity, these properties are grouped as follows:
#
# | <b><u>Strength</b></u>              | <b><u>Rigidity</b></u>                  |
# |:------------------------------------|:----------------------------------------|
# | $ \sigma_t \times A $ (tension)     | $ E \times A $ (tension or compression) |
# | $ \sigma_c \times A $ (compression) |                                         |
# | $ \tau \times A $ (shear)           | $ E_s \times A $ (shear)                |
# | $ \sigma_t \times S $ (bending)     | $ E \times I $ (bending)                |
# | $ \sigma_c \times S $ (bending)     | $ E_s \times R $ (torsion)              |
#
# Notice that the rigidity of a member (its ability to reflect deflection) in bending is measured by the product of its modulus of elasticity ($ E $) and its moment of inertia ($ I $). All steels have the same modulus of elasticity ($ E $); therefore, it is quickly seen that a high-strength alloy steel will not improve the stiffness of a member.

# %% [markdown]
# ### 1.2.8 Stress and Strain Factors in Design Formulas
#
# Stress and strain are given in the following terms:
#
# 1. Stress
#     $ \sigma_t $ = tensile stress
#     $ \sigma_c $ = compressive stress
#     $ \tau $ = shear stress
# 2. Strain is a unit movement (inches per linear inch) which is usually expressed as an over-all movement as follows:
#     $ e $ = elongation or contraction, tension or compression
#     $ \Delta $ = vertical deflection, bending or shear
#     $ \theta $ = angular twist, torsion

# %% [markdown]
# ## 1.3 Problem Definition

# %% [markdown]
# ### 1.3.1 The Importance of Problem Definition
#
# Properly determining the forces in a given situation is obviously important. Improperly determining the forces within a member will result in incorrect design.

# %% [markdown]
# ### 1.3.2 - Load Analysis
#
# When a load is placed on a member, stress and strain result. Stress is the internal resistance to the applied force. Strain is the amount of "give" or deformation caused by the stress, such as deflection in bending, elongation in tension, contraction in compression, and angular twist in torsion.
#
# The section modulus ($ S $) is the property that determines a beam's suitability in strength. The formulas of Table 1 show that the section moduli for two designs of of equivalent strength vary inversely as their allowable tensile strengths.
#
# The property that determines how suitable a beam is for rigidity is its moment of inertia ($ I $). The formulas below show that the moments of inertia for two designs of equivalent rigidity vary inversely as their moduli of elasticity ($ E $).
#
# In comparing two or more designs, if similar sections are used and the outside dimensions including the depth are the same, the values of the section area ($ A $), the moment of inertia ($ I $) and the section modulus for the stress on the bottom surface ($ S $) will vary as teh thickness of the section. This relationship does not hold true in the strictest sense, but from a practical standpoint is very close and sufficient for most purposes. Notice this relationship in the two similar sections of Figure 1.
#
# ![image.png](attachment:77034ff1-9442-49ef-899e-44134339c65a.png)
#
# | <u><b>Frame 1</u></b> | <u><b>Frame 2</u></b> |
# |:---------------------:|:---------------------:|
# | t = 1 $ in. $         | t = 1/2 $ in. $       |
# | A = 38.0 $ in^2 $     | A = 19.5 $ in^2 $     |
# | I = 359.7 $ in^4 $    | I = 193.8 $ in^4 $    |
# | S = 50.5 $ in^3 $     | S = 23.9 $ in^3 $     |

# %%
from civilpy.general import units

# %%
t_1 = 1 * units.inch
t_2 = .5 * units.inch

A_1 = 38.0 * units.inch ** 2
A_2 = 19.5 * units.inch ** 2

I_1 = 359.7 * units.inch ** 4
I_2 = 193.8 * units.inch ** 4

S_1 = 50.5 * units.inch ** 3
S_2 = 23.9 * units.inch ** 3

print(f"t ratio = {(t_2/t_1 * 100).magnitude}%")
print(f"A ratio = {(round(A_2/A_1 * 100, 1)).magnitude}%")
print(f"I ratio = {(round(I_2/I_1 * 100, 1)).magnitude}%")  # Book has this value incorrect
print(f"S ratio = {(round(S_2/S_1 * 100, 1)).magnitude}%")
# Out:
# t ratio = 50.0%
# A ratio = 51.3%
# I ratio = 53.9%
# S ratio = 47.3%

# %% [markdown]
# <u><b>Problems</u></b>
#
# The following problems serve to illustrate the importance of load analysis.
#
# A fabricating plant sets up an automatic welding head on a boom, Figure 2, with the work moving beneath it on a track. Now, at a later date, it is necessary to extend the length of this boom because of the larger tanks being fabricated.
#
# In defining his problem, the engineer recognizes this as a simple cantilever beam with a concentrated load at the outer end. Knowing the weight of the automatic welding head with its wire reel and flux, he then sets up an allowable vertical deflection of about 1/8" under this load. Even though there is no known horizontal force applied to this beam, he assumes this could possibly reach about 1/4 of the vertical force. He does this to build in some horizontal stability.
#
# ![image.png](attachment:c79baa88-5831-4baf-82a3-a117131385e4.png)
#
# The result is a simple box section, deeper than it is wide. Now, how does this perform?
#
# When the welding head is mounted on the end of the new boom, the boom deflects downward 1.8", and there it will remain for the 20 years until it is replaced or moved to another location. During the operation of the welding head, the fixture may vibrate slightly, perhaps from being accidentally bumped by the operator, perhaps from a crane passing overhead and shaking the building framework. At any rate, this boom will probably vibrate a greater distance horizontally than vertically, because the moment of inertia about the vertical y-y axis ($ I_y $) is muhc less than that about the horizontal x-x axis ($ I_x $). If the speed of travel of welding is not too great, the welding head will automatically adjust vertically to maintain constant arc length. There is no such control for horizontal vibrations.
#
# Perhaps the real design problem is to maintain proper stiffness against possible movement of the boom, which is greatest in the horizontal direction. This might result in a different section of boom than previously designed.  It would probably look like the original cross-section (Fig. 2) rotated 90° on its longitudinal centerline.
#
# <center>*&emsp;&emsp;&emsp;&emsp;&emsp;*&emsp;&emsp;&emsp;&emsp;&emsp;*</center>
#
# Table 1 - Formulas for Equivalent Strength and Rigidity
#
# <u><b>For Designs of Equivalent Strength in Bending</u></b>
#
# $ M = K*P*L,\ and\ M=\sigma S $
#
# where:
#
# $ K $ = beam constant
# $ M $ = moment
# $ P $ = load
# $ L $ = length of beam
# $ \sigma $ = bending stress
# $ S $ = section modulus (=I/c)
#
# therefore:
#
# $ \sigma S = K * P * L $
#
# Comparing two designs to carry the same load (P):
#
# $ \sigma_1 S_1 = K_1 * P_1 * L_1 $
#
# $ \sigma_1 S_2 = K_2 * P_2 * L_2 $
#
# or, for equivalent strength -
#
# $ \sigma_1 S_1 = \sigma_2 S_2 $
#
# <u><b>For Designs of Equivalent Rigidity in Bending</u></b>
#
# $$ \Delta = \frac{K * P * L^3}{E * I} $$
#
# where:
#
# $ \Delta $ = deflection
# $ E $ = modulus of elasticity (tension)
# $ I $ = moment of inertia
#
# Comparing two designs to carry the same load (P), with the same deflection ($\Delta$):
#
# $$ \Delta_1 = \frac{K_1 * P_1 * L_1 ^3}{E_1 * L_1} $$
#
# $$ \Delta_2 = \frac{K_2 * P_2 * L_2^3}{E_2 * L_2} $$
#
# or for equivalent rigidity -
#
# $ E_1 I_1 = E_2 I_2 $

# %% [markdown]
# ![image.png](attachment:5892341f-6325-4e99-89d2-bc78387f6522.png)
#
# | &nbsp; | &nbsp; | &nbsp; |
# |:-------:|:-:|:----:|
# | $ I $   | 1 | 1.4  |
# | $ S $   | 1 | 0.44 |
# | $ W_t $ | 1 | 0.26 |
#
# Fig. 3 - When the distance from the neutral axis to the outer fiber increases faster than the resulting moment of inertia, the section modulus (strength) decreases.
#
# Usually the designer is interested in as much strength and stiffnes as they can economically obtain. Yet, if the design problem is properly defined, a certain amount of flexibility may have to be designed into the member. For example, some parts of farm implements must have some flexibility to stand up to constant usage.
#
# For example, an engineer has designed a simple beam from a 1/4" x 2" flat bar. Under load, it has a deflection of .0016". He believes this should be made "stronger," so he designs a formed channel section from 16-gage steel. Under the same load, it deflects only .0012". This appears to be a substantial improvement; but when the beam is acidentally overloaded, teh engineer is surprised to find that his "stronger" beam is actually the weaker beam. The confusion results from the hazy concept of "strong", instead of a clear understanding of the properties of a section.
#
# The property of a section which indicates its resistance to bending is the moment of inertia (I). The property which indicates it's strength in bending is the section modulus (S). Using the original flat bar as a basis, its properties are assigned a factor of 1; see Figure 3. Therefore, the redesign has relative properties as shown.
#
# The first test for vertical deflection using a gage dial to make the measurement, depended only on the moment of inertia (I). The new channel section has an I value of 1.4 times that of the original, which accounts for the reduction in deflection from .0016" to .0012". A second test, under overload, depended only on the section modulus (S). The new channel section has an S value of 44% that of the flat bar, which accounts for the resulting bending stress far exceeding the yield point of the material. Thus, buckling of the new section occurred. In contrast, the bending stress in the original flat bar was held much below the yield point, and that member is still serving it's purpose.

# %% [markdown]
# <center>*&emsp;&emsp;&emsp;&emsp;&emsp;*&emsp;&emsp;&emsp;&emsp;&emsp;*</center>
#
# In most cases, when a given section is "beefed up" to increase its stiffness (moment of inertia, I), its strength will automatically increase (section modulus, S) so that the engineer seldom checks the resulting section modulus. There are exceptions.
#
# In the example, Figure 4, the addition of stiffeners (B) increases the moment of inertia (stiffness) to 134% of the plate (A); yet the section modulus (strength) is only 67% of the plate. The reasons for this is very simple, yet is quite often overlooked. Section modulus (S) is equal to the moment of inertia (I) divided by the distance from the neutral axist to the outer fiber (c).
#
# The distance to the outer fiber (c) for the flat plate is one-half of the plate thickness, or 3/8".
#
# ![image.png](attachment:eac8900e-89bf-4ae0-bbbf-4d494d68fe41.png)
#
# | Section | Moment of Inertia (I) | Section Modulus (S) | Weight lbs/ft | Rigidity$^1$ | Strength$^1$ | Weight$^1$ |
# |:-------:|:---------------------:|:-------------------:|:-------------:|:------------:|:------------:|:----------:|
# |  A      | .53                   | 1.41                | 38            | 1            | 1            | 1          |
# |  B      | .71                   | .95                 | 39.5          | 1.34         | .67          | 1.05       |
#
# $^1$ - Relative Values

# %%
a_c = 0
b_c = .75 * units.inch

# %% [markdown]
# $$ S = \frac{I}{c} = \frac{1.34}{2} = 0.67 $$

# %%
I_a = (15 * units.inch * .75 * units.inch ** 3) / 12
I_b = (.25 * units.inch * .375 * units.inch ** 3) / 12

A_a = 15 * units.inch * .75 * units.inch
A_b = .25 * units.inch * .375 * units.inch

Ad_a_2 = 0
Ad_b_2 = A_b * b_c ** 2

I_a + Ad_a_2 + I_b + Ad_b_2
# Out:
# <Quantity(0.998046875, 'inch ** 4')>

# %% [markdown]
# <b><u>Python Demo - Calculating Section properties of a member</u></b>
#
# //TODO - Refine the process for performing this, add some form of visualization aid

# %%
class SectionComponent:
    """
    Class to hold the values for the individual members of a built up section that will later
    be used to calculate properties of the full section like neutral axis, momement of inertia, etc.

    If the shape is anything other than a rectangle (representing a plate) the area of the shape must
    be passed to the object as a value and the `irregular_shape` value should be set to `True`.
    """
    def __init__(self, dimensions = (None, None), offset=(None, None), irregular_shape=False, area=None):
        self.x = dimensions[0]
        self.y = dimensions[1]
        self.x_bar = offset[0] + (self.x / 2)
        self.y_bar = offset[1] + (self.y / 2)
        self.irregular_shape = irregular_shape
        self.area = area
        self.calculate_component_properties()

    def calculate_component_properties(self):
        if not self.irregular_shape:
            self.area = self.x * self.y

# %%
test_object = SectionComponent(dimensions = (2 * units.inch, 10 * units.inch), offset = (0. * units.inch, 0. * units.inch))
print(test_object.x_bar)

test_object_2 = SectionComponent(dimensions = (20 * units.inch, 5 * units.inch), offset = (0. * units.inch, 10. * units.inch))
# Out:
# 1.0 inch

# %%
class Section:
    """
    Class to define a built up section and calculate the section properties of the 
    built up section.
    """
    def __init__(self, components=[]):
        self.components = components
        self.area = sum([component.area for component in self.components])
        self.neutral_y_axis = sum([component.area*component.y_bar for component in self.components]) / self.area
        self.neutral_x_axis = sum([component.area*component.x_bar for component in self.components]) / self.area
        self.moment_of_inertia_x()

    def moment_of_inertia_x(self):
        for component in self.components:
            if not component.irregular_shape:
                self.I_x = (component.x * component.y ** 3) / 12 + (component.y_bar - self.neutral_y_axis) ** 2 * component.area
            else:
                # //TODO - Determine how to handle this case
                pass

# %%
test_beam = Section(components=[test_object, test_object_2])
test_beam.I_x
# Out:
# <Quantity(364.583333, 'inch ** 4')>

# %% [markdown]
# Neutral axis calculation
#
# $$ c = \frac{\sum_i \bar y_i  \bar A }{\sum_i \bar A } $$

# %%
# As a demonstration, here's a demonstration of an irregular section
# The section consists of a 40"x5" top flange and a 5"x35" web
c = (
       (37.5 * units.inch * 40 * units.inch * 5 * units.inch) + 
       (5 * units.inch * 35 * units.inch * 17.5 * units.inch)
    ) / (
        5 * units.inch * 35 * units.inch + 5 * units.inch * 40 * units.inch
    )

print(round(c, 3))
# Out:
# 28.167 inch

# %%
A_1 = 5 * units.inch * 35 * units.inch
A_2 = 40 * units.inch * 5 * units.inch

# %%
y_1 = c - 35 * units.inch / 2
y_2 = 35 * units.inch + 2.5 * units.inch - c

# %%
I_1 = (5 * units.inch * (35 * units.inch) ** 3) / 12
I_2 = (40 * units.inch * (5 * units.inch) ** 3) / 12

# %%
I = I_1 + y_1 ** 2 * A_1 + I_2 + y_2 ** 2 * A_2
round(I, 1)
# Out:
# <Quantity(55614.6, 'inch ** 4')>

# %% [markdown]
# An example of the process by integration

# %%
from sympy import *

# %%
y = Symbol('y')

# Define the two integrals
integral1 = integrate(5*y**2, (y, -28.167, 6.833))
integral2 = integrate(40*y**2, (y, 6.833, 11.833))

# Calculate the sum of the integrals
total_integral = integral1 + integral2
round(total_integral * units('in^4'), 1)
# Out:
# <Quantity(55614.6, 'inch ** 4')>

# %% [markdown]
# ### 1.3.3 - Material Selection
#
# After loads are established and evaluated material should be selected. Two examples are provided, imagine a group of engineers trying to increase the rigidity of a component. They try multiple types of steel. Since all steels have the same modulus of elasticity, they all perform the same in terms of rigidity.
#
# The second example is a lever that operates at high speeds. Since the load on the lever is low, the primary component of the force acting on that lever is the result of it's mass. Therefore, if a lighter material is used, the deflection of the lever would as a result, also be reduced.
#
# consider the formulas:
#
# $$ \Delta = \frac{K*F*L^3}{EI} $$
#
# and $$ F = Ma $$
#
# therefore;
#
# $$ \Delta = \frac{K*m*a*L^3}{E * I} $$
#
# where:
#
# $ \Delta $ = deflection
#
# $ K $ = beam constant
#
# $ m $ = mass
#
# $ a $ = acceleration or deceleration
#
# $ E $ = modulus of elasticity (tension)
#
# $ I $ = moment of inertia
#
# $ L $ = length
#
# Since:
#
# density of steel = $7.9$
#
# density of alumninum = $2.8$
#
# E of steel = $ 30 \times 10 ^ 6 $
#
# E of aluminum = $ 10.3 \times 10 ^ 6 $
#
# Inserting the ratios of these values (steel to aluminum) into the above deflection formulas;
#
# $$ \Delta_{AL} = \frac{1 * \big(\frac{2.8}{7.9}\big) * 1 * 1 ^ 3}{\Big(\frac{10.3 \times 10^6}{30 \times 10^6} * 1 \Big)} \Delta_{St} $$

# %%
delta_al = (1 * (2.8/7.9) * 1 * 1 ** 3 ) / ((10.3e6 / 30e6) * 1)
round(delta_al, 2)
# Out:
# 1.03

# %% [markdown]
# Thus the aluminum lever designed for equivalent rigidity would actually have resulted in a deflection 1.03 times greater than the steel option. The problem was solved by redesign of the steel lever and not by material substitution.
#
# <center>*&emsp;&emsp;&emsp;&emsp;&emsp;*&emsp;&emsp;&emsp;&emsp;&emsp;*</center>
#
# Steel has greater strength than any other commercially available material. If still more section strength is required, a higher-strength alloy steel may be used instead of the usual machine or structural steels.
#
# Steel has greater rigidity or stiffness than any other commercially available material. This property is measured in terms of the material's modulus of elasticity. Refer to fig. 5 for the relative stiffness of several commercial materials. All samples have the same section and are loaded so that all deflect the same amount.  The relative weights on the samples indicate how the materials differ in their stiffness or modulus of elasticity.
#
# ![image.png](attachment:8cc5658c-02e2-4227-bc0b-3de94d62e95d.png)
#
# Fig. 5 - Comparative stiffness of various materials. Steel supports a greater weight for same deflection as other materials.
#
# Even though aluminum and magnesium are lighter than steel, their moduli of elasticity are less than that of steel by a greater ratio. Aluminum has a density 35.4% that of steel, yet its modulus of elasticity is only 34.4% of steel's. Magnesium has a density of 22.8% that of steel, but a modulus of elasticity only 21.6% of steels. A steel section -- for the same stiffness or rigidity -- will weigh less than a corresponding section of aluminum or magnesium, provided the steel section can have the same depth.
#
# Since aluminum's modulus of elasticity is only 34.4% that of steel, it requires a moment of inertia 2.9 times that of steel or a sectional area approximately 2.9 times that of steel for equivalent rigidity. With a density 35.4% that of steel, the aluminum section would have an over-all weight of 1.03 times that of steel.
#
# Conclusion: weight for weight, mild steel is still the lightest, most economical metal for equivalent rigidity.

# %% [markdown]
# ## 1.4 - Designers Guide to Effecient Use of Steel

# %% [markdown]
# ### 1.4.1 - Design for Efficient Use of Steel
#
# Experienced designers who produce successful designs follow a definite sequence in doing so.  The process is a creative process where more options are theorized than are fleshed out. This section presents the major design and fabrication considerations in an easily followed sequence. The sequence serves as both an introduction as well as later reference for the engineer. The sequence is presented as a series of checklists that constitue a practical systems approach to designing for maximum economy and the best functional designs producible under given manufacturing conditions.

# %% [markdown]
# ### 1.4.2 - Designer's Guide to the Efficient Use of Steel
#
# Here is the master check list to help guide designers through the system approach to designing with steel in a way which achieves economy and improves the function of the end product. The list is applicable to either designing one part at a time or designing full systems.
#
# 1. Recoginition of the Problem
# 2. Analysis of the Present Design
# 3. Determination of Load Conditions
# 4. Major Design Considerations
# 5. Layout
# 6. Plate Preparation
# 7. Special Sections and Forming
# 8. Welded Joint Design
# 9. Size and Amount of Welds
# 10. Use of Subassemblies
# 11. Use of Jigs, Fixtures and Positioners
# 12. Assembly
# 13. Welding Proceedure
# 14. Control and Correction of Distortion
# 15. Cleaning and Inspection
#
# Some of these refer to manufacturing. These are important to the designer in evaluating the producibility of a proposed design, and in contributing more fully to the planning process. Each checklist item is broken down further in the following sections.

# %% [markdown]
# #### 1.4.2.1 - Recognition of Problem
#
# 1. Is this an entirely new system or a redesign of an existing system
# 2. If a redesign problem, should the conversion to steel be made a part at a time, or a whole new systemic approach to meeting the basic requirements?
# 3. What are the primary and secondary functions of the proposed system?
# 4. Relate every detail of existing and proposed designs to performance of the system. Continue to do so as the proposed design develops and takes shape.

# %% [markdown]
# #### 1.4.2.2 - Analysis of Present Design
#
# 1. Is the system larger, heavier, more rigid, or capable of longer life than required?
# 2. What do service records reveal as to the demand for replacment components? Examine any available history of failures, warranty claims, and owner complaints. Perhaps the system was overdesigned in some respects, while other members may need to be beefed up.
# 3. What parts must remain interchangeable so as to meet future need for replacement parts for systems presently in service? Be careful that any such reasoning is sound. In the extreme, it could delay modernization of of design for years and permit competition to capture your original equiment market.
# 4. What do your customers say about the machine? And, what does your sales force think is right or wrong with it?
# 5. What features of the present design must be retained?
# 6. What new features must be added?
# 7. Have you or other team members had any new ideas which they wanted to use on this machine, but haven't be able to because the design was frozen? Now would be the time to review these suggestions.
# 8. Is the appearance dated, non-functional?
# ~~9. If the new design is to be based on present cast design, are there any parts now attached to a major casting which might be made integral with the weldment?~~
# ~~10. If the new design is to be based on present cast design, are the present thicknesses of various sections actually required for strength, rigidity or functional reasons? Or, did foundry practice make these necessary?~~
#
#
#
# <div class="warning" style='padding:0.1em; background-color:#E9D8FD; color:#69337A'>
#     <span>
#         <p style='margin-top:1em; text-align:center'>
#             <b>(The last two aren't applicable to bridge design)</b>
#         </p>
#     </span>
# </div>

# %% [markdown]
# #### 1.4.2.3 - Determining Load
#
# It is first necessary to define what work the system must do; then, what conditions of service may cause overloads and vibrations. From such information, the load on individual members can be determined.
#
# In seeking a starting point from which or to which loading can be calculated the designer may find one or more of the following practical.
#
# ~~1. From the motor horsepower and speed, determine the torque (in inch-pounds) on a shaft or revolving part.~~
# 2. Calculate in pounds the force on a machine member created by the dead weight of parts.
# 3. Load on the members of a hoist or lift truck can be figured back from the load required to tilt the machine.
# 4. On a shovel or ditch digger, for example, teh maximum strength of critical cables proven satisfactory in service can be used to work back to the load on machine parts.
# 5. THe maximum force required to shear a critical pin may be used as a starting point.
# 6. If a satisfactory starting point cannot be found, design for an assumed load and adjust from experience and test.

# %% [markdown]
# #### 1.4.2.4 - Major Design Factors
#
# Design is not a linear process, so there are times these checklists won't be able to be followed to a T during an iterative process. To help save rework, the designer should think ahead as much as practical.
#
# the following factors determine the performance of the design;
#
# 1. Design should satisfy strength and stiffness requirements. Overdesign costs money in extra material, welding and handling costs.
# 2. Check safety factor being used. Past experience of performance might indicate that it is set too high, at an unnecessary expense.
# 3. Specify appearance required. Appearance for its own sake usually increasses cost more than necessary. Many welds are completely hidden from view. The welder not likely to know which welds are critical appearance-wise and which are not, unless print specifies them.
# 4. If code work, check restrictions to ascertain that most economical method allowed by code is being used.
# 5. Use deep sections to resist bending.
# 6. Symmetrical sections are more efficient for resistance to bending.
# 7. Weld ends of beams rigid to supports. This increases strength and stiffness (Fig. 1)
# 8. Proper use of stiffeners will provide rigidity with less weight (Fig. 2).
# 9. Use closed sections or diagonal bracing for torsion (twisting). A closed section, for example, may be several times better than an open section (Fig. 2).
# 10. Specify non-premium grades of steel wherever possible. Remember that higher carbon and alloy steels require preheating, and frequently postheating, which are added cost items.
# 11. Place higher grades of steel only where required, and use mild steel for the rest of the structure (Fig. 3).
# 12. Remember that high-strength steels and other premium materials are not available in as wide a range of standard mill shapes, from stock, as the lower-priced mild steels.
# 13. If only surface properties (vis. wear-resistance) of a higher-priced or difficult-to-weld material are needed, consider using a mild steel base and hardsurfacing to obtain the desired properties (Fig. 4).
# 14. Consider first the use of standard rolled sections (Fig. 5). These require less forming and welding.
# 15. Choose sections according to a planned factory stock list.
# 16. When delivery time is short or production is low, use plate and bar sizes in stock or easy to get.
# 17. For maximum economy, use plate and bar sizes standardized for your own or other industries.
# 18. If bar or plate surface must be machined or ground or hardsurfaced, dimension the section so that initial plate and bar sizes can be readily obtained from plant or vendor inventory (Fig. 6).
# 19. Provide maintenance accessibility. Do not bury a bearing support or other critical wear point within a closed-box weldment.
# 20. Sometimes sections can be designed round so that automatic welding can be used more advantageously (Fig. 7).
# 21. On special machines especially, consider possibility of economies in using commercially available standard index tables, way units, heads, columns, and chassis.
#
# ![image.png](attachment:ca8ca32e-b94f-47b4-a5e1-a1a733f33f00.png)
#
# ![image.png](attachment:f8493d7d-469a-4d2e-a718-9d700b383fd3.png)
#
# ![image.png](attachment:d1d4977d-f182-4bbe-af7a-5d6d7c13c729.png)
#
# ![image.png](attachment:0829e6d3-5b68-4f0e-bb33-9a1911151d12.png)
#
# ![image.png](attachment:2422883d-b3e8-407f-b852-7108d5ff9fe2.png)
#
# ![image.png](attachment:f948a35d-b942-4dc4-967e-ff8d409ada01.png)

# %% [markdown]
# #### 1.4.2.5 - Layout
#
# Welded components present opportunity for a wide variety of arragements. This variety provides many opportunities for savings.
#
# 1. Design for easy handling of materials and for inexpensive tooling
# 2. Check with shop for ideas where shop experience can contribute to better methods or cost savings. Do this before finalizing design.
# 3. CHeck tolerances and press fits first specified. Shop may nto be able to economically hold them. Close tolerances and fits may not be required.
# 4. Lay out for fewer number of pieces (Fig. 8). This will reduce assembly time and amount of welding.
# 5. Lay out parts of various sizes and shapes to be nested when cut or stamped, so as to minimize scrap (Fig. 9).
# 6. If possible, modify shape and size of scrap cutouts so that material may be used later for other parts: pads, stiffeners, gear blanks, etc. (Fig. 10).
# 7. If a standard rolled-to-shape section is not available, consider tehese choices:
#     1. A large plate flame-cut to developed blank size and then formed up into section;
#     2. Long flat bar stock welded together; or
#     3. Special older rolled-to-shape section the economy of which will depend upon the footage involved, the number of operations saved, and whether the contour can be developed by standard mill rolls.
# 8. For heavy rings, cut segments from plate and nest so that little scrap is produced (Fig. 11).
# 9. Welding small blanks or pieces of scrap may eliminate extensive cutting from plate, machining, and loss of material (Fig. 12).
#
# ![image.png](attachment:70c35801-c09d-4545-a454-83a9f72b6b36.png)
#
# ![image.png](attachment:ca6a98a2-26f1-4405-9a71-2e818c82b3ed.png)
#
# ![image.png](attachment:4ec3ca90-3ade-4d56-9db8-43c6585deb83.png)
#
# ![image.png](attachment:fc22028e-ea3e-4498-aa85-77a9448144c0.png)
#
# ![image.png](attachment:59393558-d8f8-425b-ae89-75f8310786ac.png)
#
# ![image.png](attachment:2968cb72-bbb8-4b28-b2f5-e9177ac5a78b.png)

# %% [markdown]
# #### 1.4.2.6 - Plate Preparation
#
# Cutting is the basic step in fabricating a weldment. Many different methods are available, the most economical will be determined by balancing several factors: material, section, quality required, and equipment available.
#
# 1. Consider the proper method of producing weldment blanks, as to which is the most economical for the quantity and quality required, principally:
#     1. Flame-cutting
#     2. Shearing
#     3. Sawing
#     4. Punch press blanking
#     5. Nibbling
#     6. Lath cut-off (for bar and tube stock)
# 2. Factor into the above evaluation, the influence of method on quality of edge for fit-up and whether method can also provide bevel (if required) for grove joints.
# 3. Consider whether dimensioning of blnak requires stock allowance or later preparation of edge and groove.
# 4. When proposing to combine cutting of blank to size and preparation of edge for welding, remember that not all welds are continuous. A continuously beveld edge that is not continuously welded may be undesirable on exposed joints.
# 5. For singl-bevel or single-V plate preparation, use single-tip flame-cutting torch.
# 6. For double-bevel or double-V plate preparation, use multiple-tip flame-cutting torch so this can be done in a single pass of the cutting machine.
# 7. If plate planer is available, a thick plate is sometimes prepared with a J or U groove because it requires less weld metal.
# 8. Consider arc-air gouging, flame gouging, or chipping for back-pass preparation, instead of machining to bevel both edges prior to welding.

# %% [markdown]
# #### 1.4.2.7 - Forming and Special Sections
#
# The second major step in forming a weldment is forming. This has limited applicabilty in Transporation engineering, but camber is probably the most obvious example in main structural members.
#
# Forming can greatly reduce the the cost of a weldment by reducing welds.
