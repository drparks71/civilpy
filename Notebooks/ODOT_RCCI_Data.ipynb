# %% [markdown]
# Source for Data:
#
# [ODOT RCCI Tool](https://experience.arcgis.com/experience/89974dcb632447e4a34ba3e13ee9f8f1/?views=View-3#data_s=geometry%3AdataSource_3-18a08c487f7-layer-3%3A%7B%22spatialReference%22%3A%7B%22latestWkid%22%3A3857%2C%22wkid%22%3A102100%7D%2C%22rings%22%3A%5B%5B%5B-9504594.119250577%2C5203300.493330156%5D%2C%5B-8902317.400942633%2C5187984.6204742035%5D%2C%5B-8917969.358782886%2C4572491.798629722%5D%2C%5B-9520246.07709083%2C4587807.671485675%5D%2C%5B-9504594.119250577%2C5203300.493330156%5D%5D%5D%7D)

# %%
import pandas as pd

crossing_df = pd.read_csv("res/rcci_data_082024.csv")

# %%
crossing_df.columns
# Out:
# Index(['Crossing ID', 'Google Maps', 'County', 'City', 'Route', 'Street',
#        'Urban Rural', 'MPO', 'RPO', 'Primary RR', 'Trains Per Day',
#        'TPD Source', 'TPD Year', 'Train Speed', 'Total Tracks',
#        'Warning Device', 'Is Shortline RR', 'Is Amtrak Service', 'Road Class',
#        'Road Lanes', 'Road Speed', 'AADT', 'AADT Truck', 'AADT Year',
#        'Crashes 5yrs', 'Crashes PDO', 'Crashes Injury', 'Crashes Fatal',
#        'Blocked Reports', 'Lat WGS84', 'LonWGS84', 'ObjectId', 'x', 'y'],
#       dtype='object')

# %%
crossing_df.nlargest(10, "Crashes 5yrs")
# Out:
#      Crossing ID                                        Google Maps    County  \
# 1797     508943S  https://www.google.com/maps/@41.69433986,-83.5...     LUCAS
# 95       509519B  https://www.google.com/maps/@41.52869413,-84.2...    FULTON
# 628      524062W  https://www.google.com/maps/@41.42027907,-82.6...      ERIE
# 1729     523793Y  https://www.google.com/maps/@41.64663337,-81.4...      LAKE
# 2423     524232N  https://www.google.com/maps/@41.42376032,-81.5...  CUYAHOGA
# 3840     524223P  https://www.google.com/maps/@41.46703101,-81.6...  CUYAHOGA
# 292      508942K  https://www.google.com/maps/@41.69454686,-83.5...     LUCAS
# 578      513832K  https://www.google.com/maps/@40.22665222,-83.3...     UNION
# 680      527980V  https://www.google.com/maps/@39.9018402,-83.69...     CLARK
# 709      472574S  https://www.google.com/maps/@41.07768214,-84.8...  PAULDING
#
#                City    Route         Street Urban Rural  \
# ...

# %%
crossing_df.nlargest(10, "Crashes PDO")
# Out:
#      Crossing ID                                        Google Maps    County  \
# 1797     508943S  https://www.google.com/maps/@41.69433986,-83.5...     LUCAS
# 95       509519B  https://www.google.com/maps/@41.52869413,-84.2...    FULTON
# 628      524062W  https://www.google.com/maps/@41.42027907,-82.6...      ERIE
# 2423     524232N  https://www.google.com/maps/@41.42376032,-81.5...  CUYAHOGA
# 292      508942K  https://www.google.com/maps/@41.69454686,-83.5...     LUCAS
# 709      472574S  https://www.google.com/maps/@41.07768214,-84.8...  PAULDING
# 899      524339R  https://www.google.com/maps/@41.39622582,-81.5...  CUYAHOGA
# 1006     523504V  https://www.google.com/maps/@39.9268213,-83.83...     CLARK
# 1616     524340K  https://www.google.com/maps/@41.39489082,-81.5...  CUYAHOGA
# 1729     523793Y  https://www.google.com/maps/@41.64663337,-81.4...      LAKE
#
#                City    Route          Street Urban Rural  \
# ...

# %%
crossing_df.nlargest(10, "Crashes Fatal").iloc[0]
# Out:
# Crossing ID                                                    228676S
# Google Maps          https://www.google.com/maps/@40.31366639,-83.0...
# County                                                        DELAWARE
# City                                                          DELAWARE
# Route                                                           CR 510
# Street                                                PENNSYLVANIA AVE
# Urban Rural                                                      Urban
# MPO                   Mid-Ohio Regional Planning Commission (Columbus)
# RPO                                                                NaN
# Primary RR                                    CSX - CSX Transportation
# Trains Per Day                                                      10
# TPD Source                                                         FRA
# TPD Year                                                          2022
# ...

# %%
crossing_df.nlargest(10, "Crashes Fatal").iloc[1]
# Out:
# Crossing ID                                                    502896R
# Google Maps          https://www.google.com/maps/@40.87728688,-80.7...
# County                                                      COLUMBIANA
# City                                                          LEETONIA
# Route                                                           CR 416
# Street                                                       WALNUT ST
# Urban Rural                                                      Urban
# MPO                                                                NaN
# RPO                           Ohio Mid-Eastern Governments Association
# Primary RR                       NS - Norfolk Southern Railway Company
# Trains Per Day                                                      48
# TPD Source                                                         FRA
# TPD Year                                                          2020
# ...
