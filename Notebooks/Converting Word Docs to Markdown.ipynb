# %%
import docx
from pylatex import Document, Section, Subsection, Command
from pylatex.utils import NoEscape
from pathlib import Path

# %%
def find_word_documents(root_folder):
    """
    Recursively finds all .docx files in the given root_folder and its subfolders.

    Args:
        root_folder (str): The root directory to start searching from.

    Returns:
        list: A list of paths to the .docx files found.
    """
    root_path = Path(root_folder)
    word_documents = list(root_path.rglob("*.docx"))
    return word_documents

# %%
list_of_word_docs = find_word_documents("D:\\MB Projects\\NS Standard Specs")

# %%
from markdownify import markdownify as md


def word_to_markdown(input_file_path, output_file_path):
    """
    Converts a Word document to a Markdown file while preserving the document structure and formatting.

    Args:
    input_file_path (str or Path): The path to the input .docx file.
    output_file_path (str or Path): The path to the output .md file.
    """
    # Load the Word document
    doc = docx.Document(input_file_path)

    # Initialize a list to hold Markdown lines
    md_content = []

    for para in doc.paragraphs:
        if para.style.name.startswith("Heading"):
            # Convert Word headings to Markdown headings
            level = int(para.style.name.split()[-1])
            md_content.append(f"{'#' * level} {para.text}")
        elif para.runs:
            # Process the paragraph for inline formatting
            md_para = ""
            for run in para.runs:
                text = run.text
                if run.bold:
                    text = f"**{text}**"
                if run.italic:
                    text = f"*{text}*"
                if run.underline:
                    text = f"__{text}__"

                # Links are handled implicitly by markdownify if present in the text
                md_para += text
            md_content.append(md_para)
        else:
            # Standard text paragraph
            md_content.append(para.text)

        # Add a line break after each paragraph to preserve structure
        md_content.append("")

    # Join all the collected Markdown lines
    final_md = "\n".join(md_content)

    # Write the Markdown content to the output file
    with open(output_file_path, "w", encoding="utf-8") as md_file:
        md_file.write(final_md)
    print(f"Markdown document saved to: {output_file_path}")

# %%
for document in list_of_word_docs:
    word_to_markdown(document, (document.parent / (document.stem + ".md")))
# Out:
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Culvert Std Spec DRAFT 08092023.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Paint Specs_Updated_11022022.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\APPENDICES\CROSSHOLE SONIC LOGGING TESTING PROCEDURES.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 1 - GENERAL\NS SPECS-FRONT END.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 1 - GENERAL\VOID\NS SPECS-FRONT END-OLD.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\020000 - TRAFFIC CONTROL AND PROTECTION.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\020005 - TEMPORARY PAVEMENT MARKINGS.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\020010 - PERMANENT PAVEMENT MARKINGS.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\020015 - SITE CLEARING.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\020020 - STRUCTURE EXCAVATION.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\020025 - STRUCTURE BACKFILL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\020030 - SOIL EROSION AND SED. CONTROL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\020040 - POROUS GRANULAR BACKFILL WITH FILTER FABRIC.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\020050 - PIPE UNDERDRAIN.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\020065 - TEMPORARY EARTH RETENTION SYSTEM.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\020075 - GABION BASKET WALL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\020080 - TEMPORARY COFFERDAM.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\2-11 FULL DEPTH PAVEMENT REMOVAL AND RIGID REPLACEMENT.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 2 - SITE WORK\2-XX GRADED AGGREGATE, TYPE B.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 3 - CONCRETE\030000 - SCOPE.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 3 - CONCRETE\030005 - CONCRETE REMOVAL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 3 - CONCRETE\030010 - SURFACE PREPARATION.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 3 - CONCRETE\030015 - CAST-IN-PLACE CONCRETE.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 3 - CONCRETE\030020 - POLYMER CONCRETE.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 3 - CONCRETE\030025 - PRECAST CONCRETE.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 3 - CONCRETE\030030 - FORMED CONCRETE REPAIR.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 3 - CONCRETE\030035 - REINFORCING STEEL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 3 - CONCRETE\030040 - CONCRETE SURFACE SEALER.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 3 - CONCRETE\030045 - DAMPPROOFING.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 3 - CONCRETE\030050 - FLOWABLE FILL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 3 - CONCRETE\030055 - EPOXY CRACK INJECTION.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 4 - STRUCTURAL STEEL\040000 - STRUCTURAL STEEL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 4 - STRUCTURAL STEEL\040005 - BEARINGS AND ASSOCIATED HARDWARE.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 4 - STRUCTURAL STEEL\040010 - ELASTOMERIC BEARINGS.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 4 - STRUCTURAL STEEL\040015 - DISC BRIDGE BEARINGS.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 4 - STRUCTURAL STEEL\040020 - BRIDGE STEEL PAINTING.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 4 - STRUCTURAL STEEL\040025 - MEMBRANE WATERPROOFING.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 4 - STRUCTURAL STEEL\040030 - MICROPILES.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 4 - STRUCTURAL STEEL\040035 - MICROPILE VERIFICATION TESTS.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 4 - STRUCTURAL STEEL\040040 - DRILLED SHAFTS.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 4 - STRUCTURAL STEEL\040045 - DRILLED SHAFT TESTING.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 4 - STRUCTURAL STEEL\040050 - SOLDIER PILE AND LAGGING WALL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 4 - STRUCTURAL STEEL\040055 - SHEET PILE WALL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 5 - MISCELLANEOUS\050000 - EXISTING STRUCTURE REMOVAL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 5 - MISCELLANEOUS\050005 - HANDRAIL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 5 - MISCELLANEOUS\050010 - STEEL WALKWAY GRATINGS.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 5 - MISCELLANEOUS\050015 - TEMPORARY WORK BRIDGE.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\DIVISION 5 - MISCELLANEOUS\050045 - CONSTRUCTION ACTIVITIES INVOLVING LEAD BASED COATINGS.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\NS Atlanta Br. 631.40 Specs_FINAL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\NS CD-290.93_Toledo_Specifications.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\NS Circleville Br. N-680.20_Specifications.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\NS Crum WV Wall NA-11.1 Specifications_90% Submittal.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS 631.40 Atlanta_Cast in Place Conc_Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS B-184.50 Nickel Plate Gr1_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS B-184.50 Nickel Plate Gr2_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS B-184.50 Nickel Plate Gr3_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS BR-292.20 Sargent_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS BR-56.20 Remington_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS CD-203.12 Elyria_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS CD-290.93 Toledo_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS H-225.06 Nace_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS ML-4.8 Pittsburgh_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS ML-6.04 Pittsburgh_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS N-680.20 Circleville_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS NA-11.1 Crum_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS RD-119.98 Cleveland_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS RD-120.07 Cleveland_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-04 CAST IN PLACE CONCRETE\NS S-69.04 Ridgeton_Cast in Place Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-05 POLYMER CONCRETE\NS 631.40 Atlanta_Polymer Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-05 POLYMER CONCRETE\NS B-184.50 Nickel Plate Gr1_Polymer Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-05 POLYMER CONCRETE\NS B-184.50 Nickel Plate Gr2_Polymer Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-05 POLYMER CONCRETE\NS BR-56.20 Remington_Polymer Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-05 POLYMER CONCRETE\NS CD-203.12 Elyria_Polymer Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-05 POLYMER CONCRETE\NS CD-290.93 Toledo_Polymer Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-05 POLYMER CONCRETE\NS ML-6.04 Pittsburgh_Polymer Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-05 POLYMER CONCRETE\NS N-680.20 Circleville_Polymer Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-05 POLYMER CONCRETE\NS NA-11.1 Crum_Polymer Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-05 POLYMER CONCRETE\NS RD-120.07 Cleveland_Polymer Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-05 POLYMER CONCRETE\NS S-69.04 Ridgeton_Polymer Conc Repair.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-06 PRECAST CONCRETE\NS 292.20 Sargent_Precast Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-06 PRECAST CONCRETE\NS B-184.50 Nickel Plate Gr1_Precast Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-06 PRECAST CONCRETE\NS BR-56.20 Remington_Precast Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-06 PRECAST CONCRETE\NS CD-203.12 Elyria_Precast Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-06 PRECAST CONCRETE\NS CD-290.93 Toledo_Precast Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-06 PRECAST CONCRETE\NS N-680.20 Circleville_Precast Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-06 PRECAST CONCRETE\NS S-69.04 Ridgeton_Precast Conc Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-07 FORMED CONCRETE REPAIR\NS B-184.50 Nickel Plate Gr1_Formed Conc Rep Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-07 FORMED CONCRETE REPAIR\NS B-184.50 Nickel Plate Gr2_Formed Conc Rep Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-07 FORMED CONCRETE REPAIR\NS CD-290.93 Toledo_Formed Conc Rep Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-07 FORMED CONCRETE REPAIR\NS N-680.20 Circleville_Formed Conc Rep Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-07 FORMED CONCRETE REPAIR\NS RD-119.98 Cleveland_Formed Conc Repair.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\3-07 FORMED CONCRETE REPAIR\NS RD-120.07 Cleveland_Formed Conc Rep Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\4-01 STRUCTURAL STEEL\NS 631.40 Atlanta_Structural Steel Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\4-01 STRUCTURAL STEEL\NS B-512.06 Stony Island_Structural Steel Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\4-01 STRUCTURAL STEEL\NS CD-203.12 Elyria_Structural Steel Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\4-01 STRUCTURAL STEEL\NS CD-290.92 Toledo_Structural Steel Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\4-01 STRUCTURAL STEEL\NS H-225.06 Nace_Structural Steel Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\4-01 STRUCTURAL STEEL\NS ML-6.04 Pittsburgh_Structural Steel Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\4-01 STRUCTURAL STEEL\NS N-680.20 Circleville_Structural Steel Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\4-01 STRUCTURAL STEEL\NS NA-11.1 Crum_Structural Steel Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\4-01 STRUCTURAL STEEL\NS RD-120.07 Cleveland_Structural Steel Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\4-01 STRUCTURAL STEEL\NS S-293.30 Atlanta_Structural Steel Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\4-01 STRUCTURAL STEEL\NS S-69.04 Remington_Structural Steel Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\4-01 STRUCTURAL STEEL\NS S-69.04 Ridgeton_Structural Steel Spec.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\03-31-21_NS Circleville_Specifications.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\5-14-21_NS Crum WV Wall_Specifications_90% Submittal.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\5-29-20_NS Remington_Specifications_100% Submittal.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\7-28-21_NS Freeburn KY Wall_Specifications_100% Submittal.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS Atlanta Br. 631.40 Specs_FINAL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS Atlanta Br. S-293.30 Specs_Addendum 2.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS B-512.06_Stony Island_Specifications.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS CD-290.93_Toledo_Specifications.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS Elyria_Specifications_100% Submittal.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS ML-4.8 Specs_100% Submittal_091721.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS ML-6.04_PA_Specifications_100%.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS Nace_Specifications_90% Submittal.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS Nickel Plate Br. B-184.50 Specs_100% Submittal_20210218.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS Nickel Plate Br. B-184.50 Specs_100% Submittal_20220401_FINAL.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS Nickel Plate Br. B-184.50_Group 3_Specs_20221020.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS RD-120.07_Cleveland_Specifications.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS Ridgeton_Specifications_100% Submittal.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\NS Sargent Br. 292.20 Specs_REV 01.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\RD_119_Cleveland_90% Submittal_Specifications_final.md
# Markdown document saved to: D:\MB Projects\NS Standard Specs\Example Specifications\Full Example Spec Sets\_NS SR 1015 Tyrone Spec Book.md

# %%
import os
import tkinter as tk
from tkinter import filedialog
import nbformat as nbf


class MarkdownToNotebookApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Markdown to Jupyter Notebook Converter")

        self.directory = tk.StringVar()

        # Entry for directory selection
        self.directory_entry = tk.Entry(root, textvariable=self.directory, width=50)
        self.directory_entry.pack(padx=10, pady=10, side=tk.LEFT)

        self.browse_button = tk.Button(
            root, text="Browse", command=self.browse_directory
        )
        self.browse_button.pack(padx=10, pady=10, side=tk.LEFT)

        # Creating a frame for the listbox with a scrollbar
        self.listbox_frame = tk.Frame(root)
        self.listbox_frame.pack(padx=10, pady=10, fill="both", expand=True)

        self.listbox = tk.Listbox(
            self.listbox_frame, selectmode=tk.EXTENDED, width=80, height=20
        )
        self.listbox.pack(side="left", fill="both", expand=True)

        self.scrollbar = tk.Scrollbar(self.listbox_frame, orient="vertical")
        self.scrollbar.config(command=self.listbox.yview)
        self.scrollbar.pack(side="right", fill="y")

        self.listbox.config(yscrollcommand=self.scrollbar.set)

        # Entry for output file name
        self.filename_frame = tk.Frame(root)
        self.filename_label = tk.Label(self.filename_frame, text="Filename:")
        self.filename_label.pack(padx=10, pady=10, side=tk.LEFT)

        self.filename_entry = tk.Entry(self.filename_frame)
        self.filename_entry.pack(padx=10, pady=10, side=tk.LEFT)

        self.filename_frame.pack(fill=tk.X)

        # Convert button
        self.convert_button = tk.Button(
            root, text="Convert", command=self.convert_files
        )
        self.convert_button.pack(padx=10, pady=10)

        self.markdown_files = []

    def browse_directory(self):
        directory = filedialog.askdirectory()
        self.directory.set(directory)
        self.load_markdown_files()

    def load_markdown_files(self):
        # Clear any existing listbox items
        self.listbox.delete(0, tk.END)

        # Recursively load markdown files from the selected directory
        self.markdown_files = {}
        for root, _, files in os.walk(self.directory.get()):
            markdown_files = [f for f in files if f.endswith(".md")]
            if markdown_files:
                relative_root = os.path.relpath(root, self.directory.get())
                for file in markdown_files:
                    full_path = os.path.join(relative_root, file)
                    self.markdown_files[full_path] = os.path.join(
                        self.directory.get(), full_path
                    )
                    self.listbox.insert(tk.END, full_path)

    def convert_files(self):
        selected_indices = self.listbox.curselection()
        selected_files = [
            self.markdown_files[self.listbox.get(i)] for i in selected_indices
        ]

        if not selected_files:
            print("No files selected.")
            return

        notebook_cells = []
        for file in selected_files:
            with open(file, "r", encoding="utf-8") as md_file:
                content = md_file.read()
                notebook_cells.append(nbf.v4.new_markdown_cell(content))

        notebook = nbf.v4.new_notebook(cells=notebook_cells)

        output_filename = self.filename_entry.get() or "output.ipynb"
        if not output_filename.endswith(".ipynb"):
            output_filename += ".ipynb"

        with open(output_filename, "w", encoding="utf-8") as nb_file:
            nbf.write(notebook, nb_file)

        print(f"Notebook saved as {output_filename}")

# %%
root = tk.Tk()
app = MarkdownToNotebookApp(root)
root.mainloop()
# Out:
# No files selected.
# No files selected.
# Notebook saved as D:\MB Projects\NS Standard Specs\test_file.ipynb
